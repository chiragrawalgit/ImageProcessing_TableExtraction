# %%
# %cd "/content/drive/My Drive/ImageProcessing_TableExtraction"

# %%
infosys_pdf = "/content/drive/My Drive/ImageProcessing_TableExtraction/docs/infosys-ar-19.pdf"

# %%
# !pip install ghostscript

# %%
import tkinter

# %%
# !pip install camelot-py[cv]

# %%
import camelot

# %%
tables = camelot.read_pdf("/content/drive/My Drive/ImageProcessing_TableExtraction/docs/ITC-Report-and-Accounts-2019.pdf",pages='152')
