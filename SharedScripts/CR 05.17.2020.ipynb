# %%
# %cd "/content/drive/My Drive/ImageProcessing_TableExtraction"

# %%
# !git status

# %%
# !git pull

# %%
file1 = "/content/drive/My Drive/ImageProcessing_TableExtraction/docs/ITC-Report-and-Accounts-2019.pdf"
file2 = "/content/drive/My Drive/ImageProcessing_TableExtraction/docs/Y_2017_e.pdf"
file3 = "/content/drive/My Drive/ImageProcessing_TableExtraction/docs/infosys-ar-19.pdf"

# %%
# !mkdir "/content/drive/My Drive/ImageProcessing_TableExtraction/docs/Infosys_Split_Images"
# %cd "/content/drive/My Drive/ImageProcessing_TableExtraction/docs/Infosys_Split_Images"

# %%
# !sudo apt install poppler-utils

# %%
# !pip install pdf2image

# %%
from pdf2image import convert_from_path

# %%
pages = convert_from_path(file3)

# %%
pages[0]

# %%
for i in range(0, len(pages)):
    page = pages[i]
    page.save( str(i) + "_page" + '.jpg', 'JPEG')

# %%
# %cd "/content/drive/My Drive/ImageProcessing_TableExtraction"
# Out:
# /content/drive/My Drive/ImageProcessing_TableExtraction

# %%
# !git add "/content/drive/My Drive/ImageProcessing_TableExtraction/docs/Infosys_Split_Images"

# %%
# !git config --global user.email = "chiragrawal.data@gmail.com"
# !git config --global user.name = "chiragrawalgit"

# %%
# !git commit -m "adding pdf pages converted to image for infosys-ar-19.pdf"
# Out:
# [master df1fe88] adding pdf pages converted to image for infosys-ar-19.pdf
#  304 files changed, 0 insertions(+), 0 deletions(-)
#  create mode 100644 docs/Infosys_Split_Images/0_page.jpg
#  create mode 100644 docs/Infosys_Split_Images/100_page.jpg
#  create mode 100644 docs/Infosys_Split_Images/101_page.jpg
#  create mode 100644 docs/Infosys_Split_Images/102_page.jpg
#  create mode 100644 docs/Infosys_Split_Images/103_page.jpg
#  create mode 100644 docs/Infosys_Split_Images/104_page.jpg
#  create mode 100644 docs/Infosys_Split_Images/105_page.jpg
#  create mode 100644 docs/Infosys_Split_Images/106_page.jpg
#  create mode 100644 docs/Infosys_Split_Images/107_page.jpg
#  create mode 100644 docs/Infosys_Split_Images/108_page.jpg
#  create mode 100644 docs/Infosys_Split_Images/109_page.jpg
#  create mode 100644 docs/Infosys_Split_Images/10_page.jpg
#  create mode 100644 docs/Infosys_Split_Images/110_page.jpg
#  create mode 100644 docs/Infosys_Split_Images/111_page.jpg
# ...

# %%
# !git push origin master
# Out:
# Counting objects: 307, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (307/307), done.
# Writing objects: 100% (307/307), 106.09 MiB | 13.78 MiB/s, done.
# Total 307 (delta 5), reused 0 (delta 0)
# remote: Resolving deltas: 100% (5/5), completed with 2 local objects.
# To https://github.com/chiragrawalgit/ImageProcessing_TableExtraction.git
#    20f9b3e..df1fe88  master -> master
